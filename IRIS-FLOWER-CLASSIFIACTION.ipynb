# %% [markdown]
# <H4>NAME : SHWETA ARVIND PATIL</H4>
# <H4>PROJECT-TITLE : IRIS-FLOWER-PREDICTION</H4>
# <H4>INTERNSHIP-PROGRAM : CODSOFT</H4>
# <H4>DOMAIN-NAME : DATA-SCIENCE</H4>

# %%
import pandas as pd

# %% [markdown]
# <H4>COLLECTION OF DATA OR LOAD DATASET</H4>

# %%
data = pd.read_csv(r"C:\Users\john\.jupyter\IRIS.csv",encoding='latin-1')
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# <H5>TOP 5 ROWS</H5>

# %%
data.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# <H5>LAST 5 ROWS</H5>

# %%
data.tail(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %% [markdown]
# <H5>TOTAL NUMBER OF ROWS AND COLUMNS</H5>

# %%
data.shape
# Out:
# (150, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# <H5>MISSING VALUES</H5>

# %%
data.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
data['sepal_length'].isnull().sum()
# Out:
# 0

# %%
data['sepal_width'].isnull().sum()
# Out:
# 0

# %%
data['petal_length'].isnull().sum()
# Out:
# 0

# %%
data['petal_width'].isnull().sum()
# Out:
# 0

# %%
data['species'].isnull().sum()
# Out:
# 0

# %% [markdown]
# <H6>THIS DATASET DOESN'T CONSIST ANY NULL VALUE SO FIXING THE NULL DATA IS NOT NEEDED</H6>

# %% [markdown]
# <H5>FINDING DUPLICATE DATA<H5

# %%
data.duplicated().sum()
# Out:
# 3

# %% [markdown]
# <H5>HANDLE DUPLICATES</H5>

# %%
data.drop_duplicates()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [147 rows x 5 columns]

# %%
print((data[['sepal_length','sepal_width','petal_length','petal_width']]<0).sum())
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# dtype: int64

# %% [markdown]
# <H5>UNIQUE-VALUES-IN-SPECIES-COLUMN</H5>

# %%
data['species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# <H5>DATA-PREPROCESSING </H5>

# %% [markdown]
# <H5>STANDARDIZATION</H5>

# %%
from sklearn.preprocessing import StandardScaler ,MinMaxScaler

# %%
numeric_columns = ['sepal_length','sepal_width','petal_length','petal_width']

# %%
scaler =  StandardScaler()

# %%
data[numeric_columns]=scaler.fit_transform(data[numeric_columns])

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0     -0.900681     1.032057     -1.341272    -1.312977  Iris-setosa
# 1     -1.143017    -0.124958     -1.341272    -1.312977  Iris-setosa
# 2     -1.385353     0.337848     -1.398138    -1.312977  Iris-setosa
# 3     -1.506521     0.106445     -1.284407    -1.312977  Iris-setosa
# 4     -1.021849     1.263460     -1.341272    -1.312977  Iris-setosa

# %% [markdown]
# <H5>NORMALIZATION</H5>

# %%
num_columns = ['sepal_length','sepal_width','petal_length','petal_width']

# %%
scaler =MinMaxScaler()

# %%
data[num_columns]=scaler.fit_transform(data[num_columns])

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0      0.222222     0.625000      0.067797     0.041667  Iris-setosa
# 1      0.166667     0.416667      0.067797     0.041667  Iris-setosa
# 2      0.111111     0.500000      0.050847     0.041667  Iris-setosa
# 3      0.083333     0.458333      0.084746     0.041667  Iris-setosa
# 4      0.194444     0.666667      0.067797     0.041667  Iris-setosa

# %% [markdown]
# <H5>DATA-VISUALIZATION</H5>

# %% [markdown]
# <H5>Data Distribution Using Histogram</H5>

# %%
data[['sepal_length','sepal_width','petal_length','petal_width']].hist(bins=20,figsize=(10,8))
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[82], line 2
#       1 data[['sepal_length','sepal_width','petal_length','petal_width']].hist(bins=20,figsize=(10,8))
# ----> 2 plt.tight_layout()
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# <H5>PAIRPLOT ON THE BASIS OF SPECIES</H5>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.pairplot(data,hue='species')
plt.show()

# %% [markdown]
# <H5>CORRELATION-METRIX-ON THE BASIS OF SEPAL AND PETAL</H5>

# %%
correlation = data[['sepal_length','sepal_width','petal_length','petal_width']].corr()

# %%
sns.heatmap(correlation, annot=True,cmap='coolwarm')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# <H5>BOXPLOT-DETECTING-OUTLIERS</H5>

# %% [markdown]
# <H6>MEASURMENT OF SEPAL AND PETAL</H6>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data= data[['sepal_length','sepal_width','petal_length','petal_width']])
plt.title("measurment of sepal and petal")
plt.show()

# %% [markdown]
# <H5>ANALYSIS OF SPECIES</H5>

# %%
group_data=data.groupby('species').mean()
group_data
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width
# species
# Iris-setosa          0.196111     0.590833      0.078644     0.060000
# Iris-versicolor      0.454444     0.320833      0.552542     0.510833
# Iris-virginica       0.635556     0.405833      0.771525     0.802500

# %% [markdown]
# <H5>BOXPLOT OF SPECIES</H5>

# %% [markdown]
# <H6>SEPAL LENGTH BY SPECIES</H6>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='species',y='sepal_length',data=data)
plt.title("sepal length by species")
plt.show()

# %% [markdown]
# <H6>PETAL LENGTH BY SPECIES</H6>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='species',y='petal_length',data=data)
plt.title("petal length by species")
plt.show()

# %% [markdown]
# <H6>SEPAL WIDTH BY SPECIES</H6>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='species',y='sepal_width',data=data)
plt.title("sepal width by species")
plt.show()

# %% [markdown]
# <H6>PETAL WIDTH BY SPECIES</H6>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='species',y='petal_width',data=data)
plt.title("petal width by species")
plt.show()

# %% [markdown]
# <H5>VIOLIN PLOT FOR PROBABILITY DENSITY</H5>

# %%
sns.violinplot(x='species',y='sepal_length',data=data)
plt.title("sepal length by species violin plot")
plt.show()

# %% [markdown]
# <H5>MACHINE LEARNING CLASSIFICATION</H5>

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# <H5>METRIX-EVALUATION</H5>

# %%
from sklearn.metrics import accuracy_score

# %%
x = data[['sepal_length','sepal_width','petal_length','petal_width']]

# %%
y=data['species']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=5)

# %%
model = DecisionTreeClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model.predict(x_test)

# %% [markdown]
# <H5>ACCURACY-SCORE</H5>

# %%
accuracy = accuracy_score(y_test , y_pred)

# %%
print(f'accuracy:{accuracy*100:.2f}%')
# Out:
# accuracy:95.56%
